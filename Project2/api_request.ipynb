# %%
#Dependencies
import pandas as pd
import numpy as np
import requests
import json
import pprint

# %%
#The base url indicates the dataset with "WWDI"
base_url = "https://www.quandl.com/api/v3/datasets/WWDI/"

# %%
api_key = "&api_key=pzEzrjcJ5yrvoXBad3uy"

# %%
country_codes = pd.read_csv("country_codes.csv", delimiter="|", error_bad_lines=False)
country_codes.head()
# Out:
#           COUNTRY CODE
# 0     Afghanistan  AFG
# 1          Africa  AFR
# 2         Albania  ALB
# 3         Algeria  DZA
# 4  American Samoa  ASM

# %%
population = {}
for index, row in country_codes.iterrows():
    try:
        var = row["CODE"]
        country = row["COUNTRY"]
        dataset = "_SP_POP_TOTL"
        query = base_url + var + dataset + "?&" + api_key
        response = requests.get(query)
        data = response.json()
        population.update({country: (data['dataset']['data'])[0][1]})
    except KeyError:
        continue
population
# Out:
# {'Afghanistan': 35530081.0,
#  'Albania': 2873457.0,
#  'Algeria': 41318142.0,
#  'American Samoa': 55641.0,
#  'Andorra': 76965.0,
#  'Angola': 29784193.0,
#  'Antigua and Barbuda': 102012.0,
#  'Arab World': 414491886.0,
#  'Argentina': 44271041.0,
#  'Armenia': 2930450.0,
#  'Aruba': 105264.0,
#  'Australia': 24598933.0,
#  'Austria': 8809212.0,
#  'Azerbaijan': 9862429.0,
#  'Bahamas, The': 395361.0,
#  'Bahrain': 1492584.0,
#  'Bangladesh': 164669751.0,
#  'Barbados': 285719.0,
#  'Belarus': 9507875.0,
#  'Belgium': 11372068.0,
#  'Belize': 374681.0,
#  'Benin': 11175692.0,
#  'Bermuda': 65441.0,
#  'Bhutan': 807610.0,
#  'Bolivia': 11051600.0,
#  'Bosnia and Herzegovina': 3507017.0,
#  'Botswana': 2291661.0,
#  'Brazil': 209288278.0,
#  'Brunei Darussalam': 428697.0,
#  'Bulgaria': 7075991.0,
#  'Burkina Faso': 19193382.0,
#  'Burundi': 10864245.0,
#  'Cabo Verde': 546388.0,
#  'Cambodia': 16005373.0,
#  'Cameroon': 24053727.0,
#  'Canada': 36708083.0,
#  'Caribbean small states': 7284294.0,
#  'Cayman Islands': 61559.0,
#  'Central African Republic': 4659080.0,
#  'Chad': 14899994.0,
#  'Channel Islands': 165314.0,
#  'Chile': 18054726.0,
#  'China': 1386395000.0,
#  'Colombia': 49065615.0,
#  'Comoros': 813912.0,
#  'Congo, Dem. Rep.': 81339988.0,
#  'Congo, Rep.': 5260750.0,
#  'Costa Rica': 4905769.0,
#  "Cote d'Ivoire": 24294750.0,
#  'Croatia': 4125700.0,
#  'Cuba': 11484636.0,
#  'Curacao': 161014.0,
#  'Cyprus': 1179551.0,
#  'Czech Republic': 10591323.0,
#  'Denmark': 5769603.0,
#  'Djibouti': 956985.0,
#  'Dominican Republic': 10766998.0,
#  'Dominica': 73925.0,
#  'East Asia & Pacific (all income levels)': 2314364990.0,
#  'East Asia & Pacific (developing only)': 2068308373.0,
#  'Ecuador': 16624858.0,
#  'Egypt, Arab Rep.': 97553151.0,
#  'El Salvador': 6377853.0,
#  'Equatorial Guinea': 1267689.0,
#  'Eritrea': 5228000.0,
#  'Estonia': 1315480.0,
#  'Ethiopia': 104957438.0,
#  'Euro area': 341465149.0,
#  'Europe & Central Asia (all income levels)': 915545801.0,
#  'Europe & Central Asia (developing only)': 415546194.0,
#  'European Union': 512461290.0,
#  'Faeroe Islands': 49290.0,
#  'Fiji': 905502.0,
#  'Finland': 5511303.0,
#  'France': 67118648.0,
#  'French Polynesia': 283007.0,
#  'Gabon': 2025137.0,
#  'Gambia, The': 2100568.0,
#  'Georgia': 3717100.0,
#  'Germany': 82695000.0,
#  'Ghana': 28833629.0,
#  'Greece': 10760421.0,
#  'Greenland': 56171.0,
#  'Grenada': 107825.0,
#  'Guam': 164229.0,
#  'Guatemala': 16913503.0,
#  'Guinea-Bissau': 1861283.0,
#  'Guinea': 12717176.0,
#  'Guyana': 777859.0,
#  'Haiti': 10981229.0,
#  'Heavily indebted poor countries (HIPC)': 765112280.0,
#  'High income: nonOECD': 330858000.0,
#  'High income: OECD': 1073822000.0,
#  'High income': 1249066228.0,
#  'Honduras': 9265067.0,
#  'Hong Kong SAR, China': 7391700.0,
#  'Hungary': 9781127.0,
#  'Iceland': 341284.0,
#  'India': 1339180127.0,
#  'Indonesia': 263991379.0,
#  'Iran, Islamic Rep.': 81162788.0,
#  'Iraq': 38274618.0,
#  'Ireland': 4813608.0,
#  'Isle of Man': 84287.0,
#  'Israel': 8712400.0,
#  'Italy': 60551416.0,
#  'Jamaica': 2890299.0,
#  'Japan': 126785797.0,
#  'Jordan': 9702353.0,
#  'Kazakhstan': 18037646.0,
#  'Kenya': 49699862.0,
#  'Kiribati': 116398.0,
#  'Korea, Dem. Rep.': 25490965.0,
#  'Korea, Rep.': 51466201.0,
#  'Kosovo': 1830700.0,
#  'Kuwait': 4136528.0,
#  'Kyrgyz Republic': 6201500.0,
#  'Lao PDR': 6858160.0,
#  'Latin America & Caribbean (all income levels)': 644137666.0,
#  'Latin America & Caribbean (developing only)': 568136842.0,
#  'Latvia': 1940740.0,
#  'Least developed countries: UN classification': 1002485957.0,
#  'Lebanon': 6082357.0,
#  'Lesotho': 2233339.0,
#  'Liberia': 4731906.0,
#  'Libya': 6374616.0,
#  'Liechtenstein': 37922.0,
#  'Lithuania': 2827721.0,
#  'Low & middle income': 6281293921.0,
#  'Low income': 732448558.0,
#  'Lower middle income': 2972642807.0,
#  'Luxembourg': 599449.0,
#  'Macao SAR, China': 622567.0,
#  'Macedonia, FYR': 2083160.0,
#  'Madagascar': 25570895.0,
#  'Malawi': 18622104.0,
#  'Malaysia': 31624264.0,
#  'Maldives': 436330.0,
#  'Mali': 18541980.0,
#  'Malta': 465292.0,
#  'Marshall Islands': 53127.0,
#  'Mauritania': 4420184.0,
#  'Mauritius': 1264613.0,
#  'Mexico': 129163276.0,
#  'Micronesia, Fed. Sts.': 105544.0,
#  'Middle East & North Africa (all income levels)': 444322417.0,
#  'Middle East & North Africa (developing only)': 379901782.0,
#  'Middle income': 5548845363.0,
#  'Moldova': 3549750.0,
#  'Monaco': 38695.0,
#  'Mongolia': 3075647.0,
#  'Montenegro': 622471.0,
#  'Morocco': 35739580.0,
#  'Mozambique': 29668834.0,
#  'Myanmar': 53370609.0,
#  'Namibia': 2533794.0,
#  'Nepal': 29304998.0,
#  'Netherlands': 17132854.0,
#  'New Caledonia': 280460.0,
#  'New Zealand': 4793900.0,
#  'Nicaragua': 6217581.0,
#  'Nigeria': 190886311.0,
#  'Niger': 21477348.0,
#  'Northern Mariana Islands': 55144.0,
#  'Norway': 5282223.0,
#  'OECD members': 1300865255.0,
#  'Oman': 4636262.0,
#  'Other small states': 30621014.0,
#  'Pacific island small states': 2419188.0,
#  'Pakistan': 197015955.0,
#  'Palau': 21729.0,
#  'Panama': 4098587.0,
#  'Papua New Guinea': 8251162.0,
#  'Paraguay': 6811297.0,
#  'Peru': 32165485.0,
#  'Philippines': 104918090.0,
#  'Poland': 37975841.0,
#  'Portugal': 10293718.0,
#  'Puerto Rico': 3337177.0,
#  'Qatar': 2639211.0,
#  'Romania': 19586539.0,
#  'Russian Federation': 144495044.0,
#  'Rwanda': 12208407.0,
#  'Samoa': 196440.0,
#  'San Marino': 33400.0,
#  'Sao Tome and Principe': 204327.0,
#  'Saudi Arabia': 32938213.0,
#  'Senegal': 15850567.0,
#  'Serbia': 7022268.0,
#  'Seychelles': 95843.0,
#  'Sierra Leone': 7557212.0,
#  'Singapore': 5612253.0,
#  'Sint Maarten (Dutch part)': 41109.0,
#  'Slovak Republic': 5439892.0,
#  'Slovenia': 2066748.0,
#  'Small states': 40324496.0,
#  'Solomon Islands': 611343.0,
#  'Somalia': 14742523.0,
#  'South Africa': 56717156.0,
#  'South Asia': 1788388852.0,
#  'South Sudan': 12575714.0,
#  'Spain': 46572028.0,
#  'Sri Lanka': 21444000.0,
#  'St. Kitts and Nevis': 55345.0,
#  'St. Lucia': 178844.0,
#  'St. Martin (French part)': 32125.0,
#  'St. Vincent and the Grenadines': 109897.0,
#  'Sub-Saharan Africa (all income levels)': 1061107721.0,
#  'Sub-Saharan Africa (developing only)': 1061011878.0,
#  'Sudan': 40533330.0,
#  'Suriname': 563402.0,
#  'Swaziland': 1367254.0,
#  'Sweden': 10067744.0,
#  'Switzerland': 8466017.0,
#  'Syrian Arab Republic': 18269868.0,
#  'Tajikistan': 8921343.0,
#  'Tanzania': 57310019.0,
#  'Thailand': 69037513.0,
#  'Timor-Leste': 1296311.0,
#  'Togo': 7797694.0,
#  'Tonga': 108020.0,
#  'Trinidad and Tobago': 1369125.0,
#  'Tunisia': 11532127.0,
#  'Turkey': 80745020.0,
#  'Turkmenistan': 5758075.0,
#  'Turks and Caicos Islands': 35446.0,
#  'Tuvalu': 11192.0,
#  'Uganda': 42862958.0,
#  'Ukraine': 44831159.0,
#  'United Arab Emirates': 9400145.0,
#  'United Kingdom': 66022273.0,
#  'United States': 325719178.0,
#  'Upper middle income': 2576202556.0,
#  'Uruguay': 3456750.0,
#  'Uzbekistan': 32387200.0,
#  'Vanuatu': 276244.0,
#  'Venezuela, RB': 31977065.0,
#  'Vietnam': 95540800.0,
#  'Virgin Islands (U.S.)': 107268.0,
#  'West Bank and Gaza': 4684777.0,
#  'World': 7530360149.0,
#  'Yemen, Rep.': 28250420.0,
#  'Zambia': 17094130.0,
#  'Zimbabwe': 16529904.0}

# %%
df = pd.DataFrame.from_dict(population, orient='index')

# %%
df
# Out:
#                                      0
# Afghanistan               3.553008e+07
# Albania                   2.873457e+06
# Algeria                   4.131814e+07
# American Samoa            5.564100e+04
# Andorra                   7.696500e+04
# Angola                    2.978419e+07
# Antigua and Barbuda       1.020120e+05
# Arab World                4.144919e+08
# Argentina                 4.427104e+07
# Armenia                   2.930450e+06
# Aruba                     1.052640e+05
# Australia                 2.459893e+07
# Austria                   8.809212e+06
# Azerbaijan                9.862429e+06
# Bahamas, The              3.953610e+05
# Bahrain                   1.492584e+06
# Bangladesh                1.646698e+08
# Barbados                  2.857190e+05
# Belarus                   9.507875e+06
# Belgium                   1.137207e+07
# Belize                    3.746810e+05
# Benin                     1.117569e+07
# Bermuda                   6.544100e+04
# Bhutan                    8.076100e+05
# Bolivia                   1.105160e+07
# Bosnia and Herzegovina    3.507017e+06
# Botswana                  2.291661e+06
# Brazil                    2.092883e+08
# Brunei Darussalam         4.286970e+05
# Bulgaria                  7.075991e+06
# ...                                ...
# Syrian Arab Republic      1.826987e+07
# Tajikistan                8.921343e+06
# Tanzania                  5.731002e+07
# Thailand                  6.903751e+07
# Timor-Leste               1.296311e+06
# Togo                      7.797694e+06
# Tonga                     1.080200e+05
# Trinidad and Tobago       1.369125e+06
# Tunisia                   1.153213e+07
# Turkey                    8.074502e+07
# Turkmenistan              5.758075e+06
# Turks and Caicos Islands  3.544600e+04
# Tuvalu                    1.119200e+04
# Uganda                    4.286296e+07
# Ukraine                   4.483116e+07
# United Arab Emirates      9.400145e+06
# United Kingdom            6.602227e+07
# United States             3.257192e+08
# Upper middle income       2.576203e+09
# Uruguay                   3.456750e+06
# Uzbekistan                3.238720e+07
# Vanuatu                   2.762440e+05
# Venezuela, RB             3.197706e+07
# Vietnam                   9.554080e+07
# Virgin Islands (U.S.)     1.072680e+05
# West Bank and Gaza        4.684777e+06
# World                     7.530360e+09
# Yemen, Rep.               2.825042e+07
# Zambia                    1.709413e+07
# Zimbabwe                  1.652990e+07
#
# [244 rows x 1 columns]

# %%
co2emissions = {}
for index, row in country_codes.iterrows():
    try:
        var = row["CODE"]
        country = row["COUNTRY"]
        dataset = "_EN_ATM_CO2E_PC"
        query = base_url + var + dataset + "?&" + api_key
        response = requests.get(query)
        data = response.json()
        co2emissions.update({country: (data['dataset']['data'])[0][1]})
    except KeyError:
        continue
co2emissions
# Out:
# {'Afghanistan': 0.29944499087552,
#  'Albania': 1.9787633120857,
#  'Algeria': 3.7174099008182,
#  'American Samoa': 0.92834701530354,
#  'Andorra': 5.8321699506456,
#  'Angola': 1.2913283150448,
#  'Antigua and Barbuda': 5.3776485461441,
#  'Arab World': 4.8602338324201,
#  'Argentina': 4.7467974546733,
#  'Armenia': 1.9027589101995,
#  'Aruba': 8.408362637892,
#  'Australia': 15.370137760423,
#  'Austria': 6.8698679296767,
#  'Azerbaijan': 3.9315606089892,
#  'Bahamas, The': 6.3232575117291,
#  'Bahrain': 23.449754825849,
#  'Bangladesh': 0.45914196480281,
#  'Barbados': 4.4901776734831,
#  'Belarus': 6.7019577052578,
#  'Belgium': 8.3281598978398,
#  'Belize': 1.407601494481,
#  'Benin': 0.61421385181193,
#  'Bermuda': 8.8383149879489,
#  'Bhutan': 1.2893213711672,
#  'Bolivia': 1.9324194987029,
#  'Bosnia and Herzegovina': 6.234719161683,
#  'Botswana': 3.2432876366163,
#  'Brazil': 2.5943882854978,
#  'Brunei Darussalam': 22.124701241669,
#  'Bulgaria': 5.8716158693499,
#  'Burkina Faso': 0.16201880623408,
#  'Burundi': 0.044485376256471,
#  'Cabo Verde': 0.93340323723447,
#  'Cambodia': 0.43775999800927,
#  'Cameroon': 0.31492806803483,
#  'Canada': 15.117158779478,
#  'Caribbean small states': 8.8845413845853,
#  'Cayman Islands': 9.1718380315014,
#  'Central African Republic': 0.066593110852834,
#  'Chad': 0.053777687771594,
#  'Chile': 4.6873766237128,
#  'China': 7.5439076414493,
#  'Colombia': 1.7595371735606,
#  'Comoros': 0.20281411932024,
#  'Congo, Dem. Rep.': 0.063369191048747,
#  'Congo, Rep.': 0.63536929330761,
#  'Costa Rica': 1.6309510622534,
#  "Cote d'Ivoire": 0.49020604624224,
#  'Croatia': 3.9738049055903,
#  'Cuba': 3.045210623608,
#  'Curacao': 37.72628905323,
#  'Cyprus': 5.260352040989,
#  'Czech Republic': 9.1659783758198,
#  'Denmark': 5.9357124821143,
#  'Djibouti': 0.79196175249188,
#  'Dominican Republic': 2.0699866344335,
#  'Dominica': 1.8642859105774,
#  'East Asia & Pacific (all income levels)': 6.2935261143181,
#  'East Asia & Pacific (developing only)': 5.7754783447708,
#  'Ecuador': 2.7617021750208,
#  'Egypt, Arab Rep.': 2.1989802463423,
#  'El Salvador': 1.0006446231756,
#  'Equatorial Guinea': 4.7338165294876,
#  'Eritrea': 0.13275869389835,
#  'Estonia': 14.848819173174,
#  'Ethiopia': 0.11912401452265,
#  'Euro area': 6.4749205482871,
#  'Europe & Central Asia (all income levels)': 6.9159912332161,
#  'Europe & Central Asia (developing only)': 7.4211902649844,
#  'European Union': 6.3791488477453,
#  'Faeroe Islands': 12.23784857295,
#  'Fiji': 1.3205747082318,
#  'Finland': 8.6607212434945,
#  'France': 4.5731821471024,
#  'French Polynesia': 2.9151348172671,
#  'Gabon': 2.7682657208219,
#  'Gambia, The': 0.26768488913639,
#  'Georgia': 2.4115419908774,
#  'Germany': 8.8893703948384,
#  'Ghana': 0.53653337778015,
#  'Greece': 6.1803372677845,
#  'Greenland': 8.9891819877431,
#  'Grenada': 2.2754983076345,
#  'Guam': 1.8426370411009,
#  'Guatemala': 1.1509779943039,
#  'Guinea-Bissau': 0.15724116670839,
#  'Guinea': 0.20749262060619,
#  'Guyana': 2.6323479518413,
#  'Haiti': 0.27053858579446,
#  'Heavily indebted poor countries (HIPC)': 0.2653421500774,
#  'High income: nonOECD': 11.660393693819,
#  'High income: OECD': 10.978027541615,
#  'High income': 10.710383222052,
#  'Honduras': 1.0752217904522,
#  'Hong Kong SAR, China': 6.3936005256242,
#  'Hungary': 4.2655749757664,
#  'Iceland': 6.059657407464,
#  'India': 1.7300004315616,
#  'Indonesia': 1.8193633190551,
#  'Iran, Islamic Rep.': 8.2830207874162,
#  'Iraq': 4.8118396861345,
#  'Ireland': 7.3139398077179,
#  'Israel': 7.8631813479071,
#  'Italy': 5.270866786403,
#  'Jamaica': 2.5932153704622,
#  'Japan': 9.5387061032716,
#  'Jordan': 3.0025147270398,
#  'Kazakhstan': 14.363169741822,
#  'Kenya': 0.31041531366616,
#  'Kiribati': 0.56436835720364,
#  'Korea, Dem. Rep.': 1.6135968412306,
#  'Korea, Rep.': 11.57034540934,
#  'Kuwait': 25.223864426496,
#  'Kyrgyz Republic': 1.6463953388741,
#  'Lao PDR': 0.29720088370577,
#  'Latin America & Caribbean (all income levels)': 3.0633070988793,
#  'Latin America & Caribbean (developing only)': 2.7811017555068,
#  'Latvia': 3.4981928816691,
#  'Least developed countries: UN classification': 0.31416304668285,
#  'Lebanon': 4.2957325523145,
#  'Lesotho': 1.1501110316271,
#  'Liberia': 0.21296766351526,
#  'Libya': 9.1868453934071,
#  'Liechtenstein': 1.1852290785682,
#  'Lithuania': 4.3780901230985,
#  'Low & middle income': 3.4761095446523,
#  'Low income': 0.32059516063274,
#  'Lower middle income': 1.4740252050728,
#  'Luxembourg': 17.36212137281,
#  'Macao SAR, China': 2.1798427598717,
#  'Macedonia, FYR': 3.6149381827634,
#  'Madagascar': 0.13042132063768,
#  'Malawi': 0.074762910046952,
#  'Malaysia': 8.0329915786404,
#  'Maldives': 3.2695598497968,
#  'Mali': 0.08322866339764,
#  'Malta': 5.4006139571703,
#  'Marshall Islands': 1.9410185640289,
#  'Mauritania': 0.66682242760684,
#  'Mauritius': 3.3531104720786,
#  'Mexico': 3.8662411126567,
#  'Micronesia, Fed. Sts.': 1.4454357544585,
#  'Middle East & North Africa (all income levels)': 6.1593560493239,
#  'Middle East & North Africa (developing only)': 3.9272533644741,
#  'Middle income': 3.8741278200766,
#  'Moldova': 1.3868291419659,
#  'Mongolia': 7.1273263481328,
#  'Montenegro': 3.5560717904183,
#  'Morocco': 1.744379974382,
#  'Mozambique': 0.30966660691446,
#  'Myanmar': 0.41660036165808,
#  'Namibia': 1.583728667157,
#  'Nepal': 0.28353852583467,
#  'Netherlands': 9.9201380752384,
#  'New Caledonia': 16.005931729155,
#  'New Zealand': 7.6865758254429,
#  'Nicaragua': 0.80852085559737,
#  'Nigeria': 0.54562211321375,
#  'Niger': 0.11107351550554,
#  'Norway': 9.2709451315417,
#  'OECD members': 9.5115222477388,
#  'Oman': 15.443167189482,
#  'Other small states': 7.5193118309608,
#  'Pacific island small states': 1.0641496863219,
#  'Pakistan': 0.89626410518214,
#  'Palau': 12.34270408647,
#  'Panama': 2.2543113627969,
#  'Papua New Guinea': 0.81464880730964,
#  'Paraguay': 0.87021929058826,
#  'Peru': 1.9934859492453,
#  'Philippines': 1.0554568459296,
#  'Poland': 7.5171515848987,
#  'Portugal': 4.3315540278483,
#  'Puerto Rico': 2.7244807668516,
#  'Qatar': 45.423239958912,
#  'Romania': 3.5161536912566,
#  'Russian Federation': 11.857527773705,
#  'Rwanda': 0.074016445670242,
#  'Samoa': 1.0297883405273,
#  'Sao Tome and Principe': 0.59433981993663,
#  'Saudi Arabia': 19.529271798342,
#  'Senegal': 0.60880911743352,
#  'Serbia': 5.282521916883,
#  'Seychelles': 5.4186779627623,
#  'Sierra Leone': 0.18492570165791,
#  'Singapore': 10.306331909983,
#  'Sint Maarten (Dutch part)': 19.461324134271,
#  'Slovak Republic': 5.6615813277442,
#  'Slovenia': 6.2136868446833,
#  'Small states': 7.3840255193821,
#  'Solomon Islands': 0.35044934526954,
#  'Somalia': 0.045046723093289,
#  'South Africa': 8.9801192972347,
#  'South Asia': 1.4614734045951,
#  'South Sudan': 0.12974935068348,
#  'Spain': 5.0338244872376,
#  'Sri Lanka': 0.88554580906071,
#  'St. Kitts and Nevis': 4.2989449003517,
#  'St. Lucia': 2.3071913207611,
#  'St. Vincent and the Grenadines': 1.9113454099875,
#  'Sub-Saharan Africa (all income levels)': 0.8404534982926,
#  'Sub-Saharan Africa (developing only)': 0.84002800220504,
#  'Sudan': 0.29973259831978,
#  'Suriname': 3.6340194332102,
#  'Swaziland': 0.92871499200446,
#  'Sweden': 4.4781821782137,
#  'Switzerland': 4.311562994091,
#  'Syrian Arab Republic': 1.5988984585293,
#  'Tajikistan': 0.6204667247417,
#  'Tanzania': 0.22134737238453,
#  'Thailand': 4.6218600316308,
#  'Timor-Leste': 0.38701400214707,
#  'Togo': 0.36269689158055,
#  'Tonga': 1.1439658921178,
#  'Trinidad and Tobago': 34.163242630268,
#  'Tunisia': 2.5870595844833,
#  'Turkey': 4.4914790257195,
#  'Turkmenistan': 12.517295340619,
#  'Turks and Caicos Islands': 6.0864874477608,
#  'Tuvalu': 1.0085258525853,
#  'Uganda': 0.13465600098555,
#  'Ukraine': 5.0207470644017,
#  'United Arab Emirates': 23.302022507882,
#  'United Kingdom': 6.4974404904512,
#  'United States': 16.490608393114,
#  'Upper middle income': 6.5881351747752,
#  'Uruguay': 1.9731508217758,
#  'Uzbekistan': 3.420722745849,
#  'Vanuatu': 0.5949932393278,
#  'Venezuela, RB': 6.0256975823513,
#  'Vietnam': 1.8035657496687,
#  'Virgin Islands (U.S.)': 3.9003870967742,
#  'West Bank and Gaza': 0.58485465664278,
#  'World': 4.9699739496685,
#  'Yemen, Rep.': 0.86483453475223,
#  'Zambia': 0.2882711410953,
#  'Zimbabwe': 0.77995584516284}

# %%
df2 = pd.DataFrame.from_dict(co2emissions, orient='index')

# %%
df2
# Out:
#                                   0
# Afghanistan                0.299445
# Albania                    1.978763
# Algeria                    3.717410
# American Samoa             0.928347
# Andorra                    5.832170
# Angola                     1.291328
# Antigua and Barbuda        5.377649
# Arab World                 4.860234
# Argentina                  4.746797
# Armenia                    1.902759
# Aruba                      8.408363
# Australia                 15.370138
# Austria                    6.869868
# Azerbaijan                 3.931561
# Bahamas, The               6.323258
# Bahrain                   23.449755
# Bangladesh                 0.459142
# Barbados                   4.490178
# Belarus                    6.701958
# Belgium                    8.328160
# Belize                     1.407601
# Benin                      0.614214
# Bermuda                    8.838315
# Bhutan                     1.289321
# Bolivia                    1.932419
# Bosnia and Herzegovina     6.234719
# Botswana                   3.243288
# Brazil                     2.594388
# Brunei Darussalam         22.124701
# Bulgaria                   5.871616
# ...                             ...
# Syrian Arab Republic       1.598898
# Tajikistan                 0.620467
# Tanzania                   0.221347
# Thailand                   4.621860
# Timor-Leste                0.387014
# Togo                       0.362697
# Tonga                      1.143966
# Trinidad and Tobago       34.163243
# Tunisia                    2.587060
# Turkey                     4.491479
# Turkmenistan              12.517295
# Turks and Caicos Islands   6.086487
# Tuvalu                     1.008526
# Uganda                     0.134656
# Ukraine                    5.020747
# United Arab Emirates      23.302023
# United Kingdom             6.497440
# United States             16.490608
# Upper middle income        6.588135
# Uruguay                    1.973151
# Uzbekistan                 3.420723
# Vanuatu                    0.594993
# Venezuela, RB              6.025698
# Vietnam                    1.803566
# Virgin Islands (U.S.)      3.900387
# West Bank and Gaza         0.584855
# World                      4.969974
# Yemen, Rep.                0.864835
# Zambia                     0.288271
# Zimbabwe                   0.779956
#
# [237 rows x 1 columns]
